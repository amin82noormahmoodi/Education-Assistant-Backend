# %%
print("1")
# Out:
# 1

# %%
from backend.utils.otp_module import otp_sender
otp_sender("aminnoormahmoodi2@gmail.com")
# Out:
# '943442'

# %%
import psycopg2

conn = psycopg2.connect(
    "postgresql://postgres:amin1382@localhost:5432/education_db"
)

print("Connected successfully!")
conn.close()
# Out:
# Connected successfully!

# %%
from backend.utils.vectordb_creator_module import create_faiss_vectordb

# %%
create_faiss_vectordb(
    json_path = r"D:\Projects\education_assistant\data\ostads\all.json",
    faiss_path = r"D:\Projects\education_assistant\backend\vectordb\ostads_faiss_index"

)
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.
